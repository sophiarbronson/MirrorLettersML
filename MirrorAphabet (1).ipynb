# %%
from io import BytesIO
from PIL import Image
from PIL import ImageFile
from PIL import ImageOps
from google.colab import drive
drive.mount('/content/drive')

ImageFile.Load_TRUNCATED_IMAGES = True

path = '/content/drive/My Drive/CI460Project/training/IMG_3237.png'

image_obj = Image.open(path)
rotated_image = image_obj.transpose(Image.FLIP_LEFT_RIGHT)
rotated_image.save(path)
rotated_image.show()

#Makes sure all images are png files
#num = 3237
#while num <= 3290:
#  os.rename("IMG_{}.HEIC".format(num), "IMG_{}.png",format(num))
#  num = (num+1)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-c20390783035> in <module>()
#      10 path = '/content/drive/My Drive/CI460Project/training/IMG_3237.png'
#      11
# ---> 12 image_obj = Image.open(path)
#      13 rotated_image = image_obj.transpose(Image.FLIP_LEFT_RIGHT)
#      14 rotated_image.save(path)
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/CI460Project/training/IMG_3237.png'

# %% [markdown]
# Link for authentication:
# https://accounts.google.com/o/oauth2/approval/v2/approvalnativeapp?auto=false&response=code%3D4%2F1AfDhmrjOVA-NRbGuZSUQ5Fpu1ldH-oiftV9lRQrKNlreNYqDA9lvyxVW5NA%26scope%3Demail%2520https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email%2520https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%2520https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%2520https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%2520https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly%2520openid%26authuser%3D0%26prompt%3Dconsent&hl=en&approvalCode=4%2F1AfDhmrjOVA-NRbGuZSUQ5Fpu1ldH-oiftV9lRQrKNlreNYqDA9lvyxVW5NA
